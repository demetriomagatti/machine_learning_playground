# %%
# %%javascript
# require(["codemirror/keymap/sublime", "notebook/js/cell", "base/js/namespace"],
#     function(sublime_keymap, cell, IPython){
#         cell.Cell.options_default.cm_config.keyMap = 'sublime';
#         var cells = IPython.notebook.get_cells();
#         for(var cl=0; cl< cells.length ; cl++){
#             cells[cl].code_mirror.setOption('keyMap', 'sublime');
#         }
#     }
# );

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load lite results from log file

# %%
import ast

test_log = pd.read_excel('results/df/test_log.xlsx').drop(['Unnamed: 0'],axis=1)
test_log['n_features'] = [len(ast.literal_eval(item)) for item in test_log['features']]
test_log.round(3).tail()
# Out:
#      auto_train  added_features  oversample  \
# 331        True               1        True
# 332        True               1        True
# 333        True               1        True
# 334        True               1        True
# 335        True               1        True
#
#                                               features  train_size  \
# 331  ['age', 'sex', 'smoking', 'high_blood_pressure...        0.66
# 332  ['age', 'sex', 'smoking', 'high_blood_pressure...        0.66
# 333  ['age', 'sex', 'smoking', 'platelets', 'serum_...        0.66
# 334  ['age', 'sex', 'smoking', 'platelets', 'serum_...        0.66
# 335  ['age', 'sex', 'smoking', 'serum_creatinine', ...        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 331                    100      df331     0.679   0.392        0.818
# 332                    100      df332     0.570   0.531        0.591
# 333                    100      df333     0.630   0.533        0.676
# ...

# %% [markdown]
# #### Results by category: all features

# %%
query = {
    'n_features': 11
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#    auto_train  added_features  oversample  \
# 1       False               0        True
# 3        True               1        True
# 2        True               1       False
# 0       False               0       False
#
#                                             features  train_size  \
# 1  ['age', 'anaemia', 'creatinine_phosphokinase',...        0.66
# 3  ['age', 'anaemia', 'creatinine_phosphokinase',...        0.66
# 2  ['age', 'anaemia', 'creatinine_phosphokinase',...        0.66
# 0  ['age', 'anaemia', 'creatinine_phosphokinase',...        0.66
#
#    robustness_iterations results_df  accuracy  recall  selectivity  precision  \
# 1                    100        df1     0.701   0.655        0.724      0.533
# 3                    100        df3     0.695   0.626        0.730      0.529
# 2                    100        df2     0.676   0.498        0.759      0.491
# 0                    100        df0     0.678   0.496        0.765      0.501
#
# ...

# %% [markdown]
# #### Results by category: no autotrain, no oversample, 2 features

# %%
query = {
    'auto_train': False,
    'oversample': False,
    'n_features': 2
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#     auto_train  added_features  oversample  \
# 40       False               0       False
# 27       False               0       False
# 49       False               0       False
# 7        False               0       False
# 28       False               0       False
#
#                                             features  train_size  \
# 40         ['ejection_fraction', 'serum_creatinine']        0.66
# 27  ['creatinine_phosphokinase', 'serum_creatinine']        0.66
# 49                 ['platelets', 'serum_creatinine']        0.66
# 7                       ['age', 'ejection_fraction']        0.66
# 28      ['creatinine_phosphokinase', 'serum_sodium']        0.66
#
#     robustness_iterations results_df  accuracy  recall  selectivity  \
# 40                    100       df40     0.729   0.500        0.840
# 27                    100       df27     0.666   0.474        0.760
# 49                    100       df49     0.633   0.432        0.727
# ...

# %% [markdown]
# #### Results by category: no autotrain, oversample, 2 features

# %%
query = {
    'auto_train': False,
    'oversample': True,
    'n_features': 2
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 83        False               0        True
# 95        False               0        True
# 105       False               0        True
# 81        False               0        True
# 82        False               0        True
#
#                                              features  train_size  \
# 83       ['creatinine_phosphokinase', 'serum_sodium']        0.66
# 95          ['ejection_fraction', 'serum_creatinine']        0.66
# 105                     ['platelets', 'serum_sodium']        0.66
# 81          ['creatinine_phosphokinase', 'platelets']        0.66
# 82   ['creatinine_phosphokinase', 'serum_creatinine']        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 83                     100       df83     0.603   0.611        0.601
# 95                     100       df95     0.731   0.577        0.806
# 105                    100      df105     0.584   0.570        0.591
# ...

# %% [markdown]
# #### Results by category: autotrain, no oversample, 2 features

# %%
query = {
    'auto_train': True,
    'oversample': False,
    'n_features': 2
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 150        True               1       False
# 117        True               1       False
# 138        True               1       False
# 137        True               1       False
# 120        True               1       False
#
#                                              features  train_size  \
# 150         ['ejection_fraction', 'serum_creatinine']        0.66
# 117                      ['age', 'ejection_fraction']        0.66
# 138      ['creatinine_phosphokinase', 'serum_sodium']        0.66
# 137  ['creatinine_phosphokinase', 'serum_creatinine']        0.66
# 120                       ['age', 'serum_creatinine']        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 150                    100      df150     0.718   0.604        0.774
# 117                    100      df117     0.668   0.523        0.742
# 138                    100      df138     0.625   0.464        0.701
# ...

# %% [markdown]
#  #### Results by category: autotrain, oversample, 2 features

# %%
query = {
    'auto_train': True,
    'oversample': True,
    'n_features': 2
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 205        True               1        True
# 193        True               1        True
# 223        True               1        True
# 172        True               1        True
# 183        True               1        True
#
#                                          features  train_size  \
# 205     ['ejection_fraction', 'serum_creatinine']        0.66
# 193  ['creatinine_phosphokinase', 'serum_sodium']        0.66
# 223                            ['sex', 'smoking']        0.66
# 172                  ['age', 'ejection_fraction']        0.66
# 183                      ['anaemia', 'platelets']        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 205                    100      df205     0.716   0.653        0.746
# 193                    100      df193     0.601   0.616        0.597
# 223                    100      df223     0.463   0.612        0.394
# ...

# %% [markdown]
#  #### Results by category: no autotrain, no oversample, 5 features

# %%
query = {
    'auto_train': False,
    'oversample': False,
    'n_features': 5
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 244       False               0       False
# 235       False               0       False
# 236       False               0       False
# 249       False               0       False
# 251       False               0       False
#
#                                               features  train_size  \
# 244  ['age', 'sex', 'smoking', 'ejection_fraction',...        0.66
# 235  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 236  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 249  ['age', 'sex', 'smoking', 'platelets', 'serum_...        0.66
# 251  ['age', 'sex', 'smoking', 'serum_creatinine', ...        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 244                    100      df244     0.729   0.515        0.834
# 235                    100      df235     0.663   0.457        0.765
# 236                    100      df236     0.624   0.443        0.710
# ...

# %% [markdown]
# #### Results by category: no autotrain, oversample, 5 features

# %%
query = {
    'auto_train': False,
    'oversample': True,
    'n_features': 5
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 264       False               0        True
# 272       False               0        True
# 263       False               0        True
# 262       False               0        True
# 278       False               0        True
#
#                                               features  train_size  \
# 264  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 272  ['age', 'sex', 'smoking', 'ejection_fraction',...        0.66
# 263  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 262  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 278  ['age', 'sex', 'smoking', 'platelets', 'serum_...        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 264                    100      df264     0.612   0.614        0.613
# 272                    100      df272     0.728   0.580        0.799
# 263                    100      df263     0.656   0.563        0.701
# ...

# %% [markdown]
# #### Results by category: autotrain, no oversample, 5 features

# %%
query = {
    'auto_train': True,
    'oversample': False,
    'n_features': 5
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 300        True               1       False
# 291        True               1       False
# 307        True               1       False
# 292        True               1       False
# 301        True               1       False
#
#                                               features  train_size  \
# 300  ['age', 'sex', 'smoking', 'ejection_fraction',...        0.66
# 291  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 307  ['age', 'sex', 'smoking', 'serum_creatinine', ...        0.66
# 292  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 301  ['age', 'sex', 'smoking', 'ejection_fraction',...        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 300                    100      df300     0.719   0.585        0.781
# 291                    100      df291     0.658   0.480        0.745
# 307                    100      df307     0.624   0.472        0.698
# ...

# %% [markdown]
# #### Results by category: autotrain, oversample, 5 features

# %%
query = {
    'auto_train': True,
    'oversample': True,
    'n_features': 5
}
query_str = ''
for key in query.keys():
    query_str = query_str + f'{key} == @query["{key}"] & ' 
query_str = query_str[:-2]

test_log_sorted = test_log.query(query_str).sort_values(by=['recall'],ascending=False).round(3)
test_log_sorted.head(5)
# Out:
#      auto_train  added_features  oversample  \
# 328        True               1        True
# 320        True               1        True
# 334        True               1        True
# 318        True               1        True
# 319        True               1        True
#
#                                               features  train_size  \
# 328  ['age', 'sex', 'smoking', 'ejection_fraction',...        0.66
# 320  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 334  ['age', 'sex', 'smoking', 'platelets', 'serum_...        0.66
# 318  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
# 319  ['age', 'sex', 'smoking', 'creatinine_phosphok...        0.66
#
#      robustness_iterations results_df  accuracy  recall  selectivity  \
# 328                    100      df328     0.714   0.638        0.753
# 320                    100      df320     0.595   0.607        0.590
# 334                    100      df334     0.579   0.570        0.586
# ...
